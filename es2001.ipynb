# %%
#import pandas as pd
#import numpy as np

#df = pd.DataFrame({
#    'Nome': ['Mario', 'Luigi', 'Peach'],
#    'età': [25, 30, 28],
#    'Città': ['Roma', 'Milano', 'Napoli']
#})

#df.loc[0,'Nome']
#df.loc[0:1,['Nome']]
#df.iloc[0:2,[0]]

#df[df['età'] > 26]

#df['Stipendio'] = [2000,2500,2200]
#df.loc[0,'Città'] = 'Firenze'
#df=df.drop('Stipendio', axis=1)

#df_sorted = df.sort_values(by='età', ascending=False)

#df.describe()
#df_sorted.head()
#df.head()
#df['età'].mean()

# %%
#import pandas as pd

#df=pd.read_csv('dati.csv')
#df=pd.read_csv('dati.csv', sep=';', header=0, encoding='utf-8')

#df["eta"] = [18, 22, 25, 30, 27, 35, 40, 45, 50, 55,
#             60, 28, 33, 38, 42, 47, 52, 58, 63, 20,
#             24, 29, 34, 39, 44, 48, 53, 57, 62, 65]

#df.to_csv("dati.csv", index=False)


#df
#df.head()

# %%
"""
import pandas as pd
import numpy as np

df=pd.DataFrame({
    'A': [1, 2, np.nan, 4],
    'B': [5, np.nan, 7, 8]
})

df.isna()
df.isnull()

df_clean= df.dropna()
df= df.fillna(0) 

df
"""

# %%
"""
import pandas as pd
import numpy as np

vendite=pd.DataFrame ({
    'Prodotto': ['A', 'B', 'A', 'B', 'A'],
    'Quantità': [10, 15, 20, 5, 30],
    'Prezzo':[100,200,100,200,100]
    })

totali=vendite.groupby('Prodotto')['Quantità'].sum()

risultato=vendite.groupby('Prodotto').agg({
    'Quantità': 'sum',
    'Prezzo': 'mean'
})

risultato
"""

# %%
"""
import pandas as pd
import numpy as np

studenti=pd.DataFrame ({
    'ID' : [1,2,3],
    'Nome' : ['Alice', 'Bob', 'Charlie']
    })

voti=pd.DataFrame ({
    'ID' : [1,2,3],
    'Matematica' : [8,7,9]
    })
risultato=pd.merge(studenti, voti, on='ID')
risultato
"""

# %%
import pandas as pd

df = pd.read_json('dati.json')

json_str = '[{"nome":"Mario", "età":25}]'
df = pd.read_json(json_str)

df.to_json('output.json', orient='records')

print(df)
# Out:
# C:\Users\Utente\AppData\Local\Temp\ipykernel_7300\1068301868.py:6: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(json_str)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 8
#       5 json_str = '[{"nome":"Mario", "età":25}]'
#       6 df = pd.read_json(json_str)
# ----> 8 df.to_json('output.json', orient='records', encoding='utf-8', indent=4)
#      10 print(df)
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# TypeError: NDFrame.to_json() got an unexpected keyword argument 'encoding'
